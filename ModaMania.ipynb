# %% [markdown]
# # **TRABALHO 01: Sistema de Loja de Roupas & Calçados: Moda Mania - Grupo 5 (Alex Rossoni, João Pedro Pagotto, Sofia de Alcantara, Thiago Carvalho, Wal Candeia)**
# - Acesse esse Jupyter Notebook [aqui](https://colab.research.google.com/drive/1-Sv9sEFtgHFk4QIsP7sj3-dh5XXw5Ugz?usp=sharing).
# - Acesse o repositório no GitHub [aqui](https://github.com/sofialctv/ModaMania).

# %%
# !pip install --user psycopg2-binary
# !pip install --user seaborn
# !pip install --user pandas

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import psycopg2
import warnings

warnings.filterwarnings('ignore')

run = psycopg2.connect(host = "pg-3280faa6-bd20241.d.aivencloud.com",
                       user = "avnadmin",
                       password = "AVNS_az1_T3HPrcMDdmihtmv",
                       port = "10341",
                       database = "defaultdb")
run
cur = run.cursor()
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # **6.1 CONSULTAS DAS TABELAS COM TODOS OS DADOS INSERIDOS (Todas)**

# %%
pd.read_sql_query("""

SELECT * FROM publico_alvo

""", run)
# Out:
#    codigo descricao
# 0       1    Adulto
# 1       2  Infantil

# %%
pd.read_sql_query("""

SELECT * FROM subcategoria

""", run)
# Out:
#    codigo  descricao
# 0       1   Feminino
# 1       2  Masculino

# %%
pd.read_sql_query("""

SELECT * FROM tamanho

""", run)
# Out:
#     codigo descricao
# 0        1        PP
# 1        2         P
# 2        3         M
# 3        4         G
# 4        5        GG
# 5        6  Infantil
# 6        7        34
# 7        8        36
# 8        9        38
# 9       10        40
# 10      11        42

# %%
pd.read_sql_query("""

SELECT * FROM cor

""", run)
# Out:
#    codigo descricao
# 0       1  Vermelho
# 1       2      Azul
# 2       3     Verde
# 3       4   Amarelo
# 4       5     Preto
# 5       6    Branco
# 6       7     Cinza
# 7       8      Rosa
# 8       9    Marrom
# 9      10      Bege

# %%
pd.read_sql_query("""

SELECT * FROM categoria

""", run)
# Out:
#    codigo descricao
# 0       1     Roupa
# 1       2   Calçado

# %%
pd.read_sql_query("""

SELECT * FROM produto

""", run)
# Out:
#     codigo    descricao  preco  fk_cor_codigo  fk_categoria_codigo  \
# 0        1      Vestido    599              1                    1
# 1        2        Blusa     70              2                    1
# 2        3       Camisa     50              3                    1
# 3        4      Moletom    150              4                    1
# 4        5       Casaco    300              5                    1
# 5        6      Jaqueta    250              6                    1
# 6        7         Saia     40              7                    1
# 7        8        Short     90              8                    1
# 8        9      Bermuda    100              9                    1
# 9       10        Calça    180             10                    1
# 10      11  Calça Jeans    200              1                    1
# 11      12         Bota    440              2                    2
# 12      13      Chinelo     22              3                    2
# 13      14        Tênis    165              4                    2
# 14      15     Sandália     77              5                    2
#
#     fk_tamanho_codigo  fk_publico_alvo_codigo  fk_subcategoria_codigo
# 0                   4                       1                       1
# 1                   2                       1                       1
# 2                   1                       1                       2
# 3                   4                       2                       2
# 4                   4                       1                       1
# 5                   3                       2                       1
# 6                   5                       1                       1
# 7                   3                       2                       2
# 8                   3                       2                       2
# 9                   2                       2                       2
# 10                  2                       2                       2
# 11                  6                       1                       2
# 12                  5                       2                       2
# 13                  6                       2                       1
# 14                  6                       1                       1

# %%
pd.read_sql_query("""

SELECT * FROM estoque

""", run)
# Out:
#     codigo  quantidade  fk_produto_codigo
# 0        1          50                  1
# 1        2          40                  2
# 2        3          30                  3
# 3        4          20                  4
# 4        5          10                  5
# 5        6          60                  6
# 6        7          70                  7
# 7        8          80                  8
# 8        9          90                  9
# 9       10         100                 10
# 10      11         110                 11
# 11      12         120                 12
# 12      13         130                 13
# 13      14         140                 14
# 14      15         150                 15

# %%
pd.read_sql_query("""

SELECT * FROM cliente

""", run)
# Out:
#    codigo               nome             cpf        telefone  \
# 0       1         João Silva  111.111.111-11  (11) 999999999
# 1       2        Maria Souza  222.222.222-22  (11) 988888888
# 2       3     Carlos Pereira  333.333.333-33  (11) 977777777
# 3       4           Ana Lima  444.444.444-44  (11) 966666666
# 4       5       Bruno Santos  555.555.555-55  (11) 955555555
# 5       6  Fernanda Oliveira  666.666.666-66  (11) 944444444
# 6       7      Ricardo Costa  777.777.777-77  (11) 933333333
# 7       8   Patricia Almeida  888.888.888-88  (11) 922222222
# 8       9    Gustavo Barbosa  999.999.999-99  (11) 911111111
# 9      10    Juliana Martins  101.010.101-01  (11) 900000000
#
#                     email  inadimplencia
# 0      joao@modamania.com          False
# 1     maria@modamania.com          False
# 2    carlos@modamania.com           True
# 3       ana@modamania.com          False
# 4     bruno@modamania.com          False
# 5  fernanda@modamania.com           True
# 6   ricardo@modamania.com          False
# 7  patricia@modamania.com          False
# 8   gustavo@modamania.com          False
# 9   juliana@modamania.com          False

# %%
pd.read_sql_query("""

SELECT * FROM compra

""", run)
# Out:
#     codigo data_compra  fk_cliente_codigo
# 0        1  2022-01-05                  1
# 1        2  2022-02-15                  2
# 2        3  2022-03-20                  3
# 3        4  2022-04-25                  4
# 4        5  2022-05-10                  5
# 5        6  2022-06-30                  6
# 6        7  2022-07-22                  7
# 7        8  2022-08-19                  8
# 8        9  2022-09-08                  9
# 9       10  2022-10-13                 10
# 10      11  2022-11-24                  1
# 11      12  2022-12-31                  2
# 12      13  2023-01-12                  3
# 13      14  2023-02-18                  4
# 14      15  2023-03-29                  5
# 15      16  2023-04-04                  6
# 16      17  2023-05-15                  7
# 17      18  2023-06-21                  8
# 18      19  2023-07-11                  9
# 19      20  2023-08-27                 10
# 20      21  2023-09-09                  1
# 21      22  2023-10-20                  2
# 22      23  2023-11-05                  3
# 23      24  2023-12-14                  4
# 24      25  2024-01-22                  5
# 25      26  2024-02-10                  6
# 26      27  2024-03-18                  7
# 27      28  2024-04-06                  8
# 28      29  2024-05-25                  9
# 29      30  2024-06-13                 10
# 30      31  2024-07-01                  1
# 31      32  2024-07-25                  2
# 32      33  2024-08-01                  3
# 33      34  2024-08-03                  4
# 34      35  2024-08-04                  5

# %%
pd.read_sql_query("""

SELECT * FROM compra_item

""", run)
# Out:
#     codigo    valor  quantidade  fk_compra_codigo  fk_produto_codigo
# 0        1   5000.0           1                 1                  1
# 1        2   8000.0           1                 2                  2
# 2        3   3000.0           1                 3                  3
# 3        4   6000.0           1                 4                  4
# 4        5   4000.0           1                 5                  5
# 5        6   2000.0           1                 6                  6
# 6        7  10000.0           1                 7                  7
# 7        8  12000.0           1                 8                  8
# 8        9   1500.0           1                 9                  9
# 9       10   7000.0           1                10                 10
# 10      11   4500.0           1                11                 11
# 11      12   5500.0           1                12                 12
# 12      13   2300.0           1                13                 13
# 13      14   3100.0           1                14                 14
# 14      15   2900.0           1                15                 15
# 15      16   4700.0           1                16                  1
# 16      17   8200.0           1                17                  2
# 17      18   3300.0           1                18                  3
# 18      19   6200.0           1                19                  4
# 19      20   4100.0           1                20                  5
# 20      21   2800.0           1                21                  6
# 21      22  10050.0           1                22                  7
# 22      23  12100.0           1                23                  8
# 23      24   1550.0           1                24                  9
# 24      25   7050.0           1                25                 10
# 25      26   4550.0           1                26                 11
# 26      27   5550.0           1                27                 12
# 27      28   2350.0           1                28                 13
# 28      29   3150.0           1                29                 14
# 29      30   2950.0           1                30                 15
# 30      31   4600.0           1                 1                  1
# 31      32   8100.0           1                 2                  2
# 32      33   3400.0           1                 3                  3
# 33      34   6100.0           1                 4                  4
# 34      35   4200.0           1                 5                  5

# %%
pd.read_sql_query("""

SELECT * FROM metodo_pagamento

""", run)
# Out:
#    codigo          descricao
# 0       1  Cartão de Crédito
# 1       2   Cartão de Débito
# 2       3                Pix
# 3       4           Dinheiro

# %%
pd.read_sql_query("""

SELECT * FROM pagamento

""", run)
# Out:
#     codigo data_vencimento data_pagamento    valor  parcela  \
# 0        1      2022-02-05     2022-02-05   5000.0        1
# 1        2      2022-03-12     2022-03-12   8000.0        1
# 2        3      2022-04-19     2022-04-19   3000.0        1
# 3        4      2022-05-22     2022-05-22   6000.0        1
# 4        5      2022-06-11     2022-06-11   4000.0        1
# 5        6      2022-07-07     2022-07-07   2000.0        1
# 6        7      2022-08-15     2022-08-15  10000.0        2
# 7        8      2022-09-30     2022-09-30  12000.0        2
# 8        9      2022-10-21     2022-10-21   1500.0        2
# 9       10      2022-11-14     2022-11-14   7000.0        2
# 10      11      2023-01-10     2023-01-10   4500.0        2
# 11      12      2023-02-25     2023-02-25   5500.0        3
# 12      13      2023-03-05     2023-03-05   2300.0        3
# 13      14      2023-04-18     2023-04-18   3100.0        3
# 14      15      2023-05-11     2023-05-11   2900.0        3
# 15      16      2023-06-27     2023-06-27   4700.0        4
# 16      17      2023-07-19     2023-07-19   8200.0        4
# 17      18      2023-08-14     2023-08-14   3300.0        4
# 18      19      2023-09-23     2023-09-23   6200.0        4
# 19      20      2023-10-08     2023-10-08   4100.0        4
# 20      21      2023-11-30     2023-11-30   2800.0        5
# 21      22      2023-12-07     2023-12-07  10050.0        5
# 22      23      2024-01-16     2024-01-16  12100.0        5
# 23      24      2024-02-05     2024-02-05   1550.0        5
# 24      25      2024-03-18     2024-03-18   7050.0        5
# 25      26      2024-04-25     2024-04-25   4550.0        6
# 26      27      2024-05-11     2024-05-11   5550.0        6
# 27      28      2024-06-06     2024-06-06   2350.0        7
# 28      29      2024-07-21     2024-07-21   3150.0        8
# 29      30      2024-08-28     2024-08-28   2950.0        8
# 30      31      2024-09-09     2024-09-09   4600.0        9
# 31      32      2024-10-22     2024-10-22   8100.0       10
# 32      33      2024-11-05     2024-11-05   3400.0       11
# 33      34      2024-12-16     2024-12-16   6100.0       12
# 34      35      2024-12-29     2024-12-29   4200.0       12
#
#     fk_metodo_pagamento_codigo  fk_status_pagamento_codigo  fk_compra_codigo
# 0                            1                           1                 1
# 1                            2                           1                 2
# 2                            3                           1                 3
# 3                            4                           1                 4
# 4                            1                           2                 5
# 5                            2                           2                 6
# 6                            3                           2                 7
# 7                            4                           2                 8
# 8                            1                           3                 9
# 9                            2                           3                10
# 10                           3                           1                11
# 11                           4                           1                12
# 12                           1                           1                13
# 13                           2                           1                14
# 14                           3                           2                15
# 15                           4                           2                16
# 16                           1                           2                17
# 17                           2                           2                18
# 18                           3                           2                19
# 19                           4                           2                20
# 20                           1                           3                21
# 21                           2                           3                22
# 22                           3                           3                23
# 23                           4                           3                24
# 24                           1                           1                25
# 25                           2                           1                26
# 26                           3                           1                27
# 27                           4                           1                28
# 28                           1                           2                29
# 29                           2                           2                30
# 30                           3                           2                31
# 31                           4                           2                32
# 32                           1                           3                33
# 33                           2                           3                34
# 34                           3                           3                35

# %% [markdown]
# # **6.2 CONSULTAS DAS TABELAS COM FILTROS WHERE (Mínimo 4)**

# %%
# 1) Consultando produtos com preço maior ou igual a 100

pd.read_sql_query("""

SELECT descricao AS Produto, preco AS Preço
FROM produto
WHERE preco > 100;

""", run)
# Out:
#        produto  preço
# 0      Vestido    599
# 1      Moletom    150
# 2       Casaco    300
# 3      Jaqueta    250
# 4        Calça    180
# 5  Calça Jeans    200
# 6         Bota    400
# 7        Tênis    150

# %%
# 2) Consultando compras realizadas entre setembro e dezembro de 2023

pd.read_sql_query("""

SELECT data_compra, fk_cliente_codigo AS Codigo_Cliente
FROM compra
WHERE data_compra BETWEEN '2023-09-01'AND '2023-12-01'

""", run)
# Out:
#   data_compra  codigo_cliente
# 0  2023-09-09               1
# 1  2023-10-20               2
# 2  2023-11-05               3

# %%
# 3) Consultando clientes que não são inadimplentes
pd.read_sql_query("""

SELECT nome AS NomeCliente, cpf, telefone, email
FROM cliente
WHERE inadimplencia = FALSE;

""", run)
# Out:
#         nomecliente             cpf        telefone                   email
# 0        João Silva  111.111.111-11  (11) 999999999      joao@modamania.com
# 1       Maria Souza  222.222.222-22  (11) 988888888     maria@modamania.com
# 2          Ana Lima  444.444.444-44  (11) 966666666       ana@modamania.com
# 3      Bruno Santos  555.555.555-55  (11) 955555555     bruno@modamania.com
# 4     Ricardo Costa  777.777.777-77  (11) 933333333   ricardo@modamania.com
# 5  Patricia Almeida  888.888.888-88  (11) 922222222  patricia@modamania.com
# 6   Gustavo Barbosa  999.999.999-99  (11) 911111111   gustavo@modamania.com
# 7   Juliana Martins  101.010.101-01  (11) 900000000   juliana@modamania.com

# %%
# 4) Consultando pagamentos realizado pelo método 'Cartão de Crédito'

pd.read_sql_query("""

SELECT data_pagamento, valor AS Valor_A_Pagar, parcela AS Qtd_Parcelas
FROM pagamento
WHERE fk_metodo_pagamento_codigo = (SELECT codigo FROM metodo_pagamento WHERE descricao = 'Cartão de Crédito');

""", run)
# Out:
#   data_pagamento  valor_a_pagar  qtd_parcelas
# 0     2022-02-05         5000.0             1
# 1     2022-06-11         4000.0             1
# 2     2022-10-21         1500.0             2
# 3     2023-03-05         2300.0             3
# 4     2023-07-19         8200.0             4
# 5     2023-11-30         2800.0             5
# 6     2024-03-18         7050.0             5
# 7     2024-07-21         3150.0             8
# 8     2024-11-05         3400.0            11

# %% [markdown]
# # **6.3	CONSULTAS QUE USAM OPERADORES LÓGICOS, ARITMÉTICOS E TABELAS OU CAMPOS RENOMEADOS (Mínimo 11)**
# - a) Criar 5 consultas que envolvam os operadores lógicos AND, OR e Not
# - b) Criar no mínimo 3 consultas com operadores aritméticos
# - c) Criar no mínimo 3 consultas com operação de renomear nomes de campos ou tabelas

# %%
# 1) Consultando produtos que custam entre R$100 e R$1.000

pd.read_sql_query("""

SELECT descricao AS Produto, preco AS Preço_Do_Produto
FROM produto
WHERE preco BETWEEN 100 AND 1000;

""", run)
# Out:
#        produto  preço_do_produto
# 0      Vestido               599
# 1      Moletom               150
# 2       Casaco               300
# 3      Jaqueta               250
# 4      Bermuda               100
# 5        Calça               180
# 6  Calça Jeans               200
# 7         Bota               400
# 8        Tênis               150

# %%
# 2) Consultando produtos da categoria 'Roupa' ou público-alvo 'Adulto'

pd.read_sql_query("""

  SELECT p.descricao AS Produto, p.preco AS Preço_Do_Produto
  FROM produto p
  JOIN categoria c ON p.fk_categoria_codigo = c.codigo
  JOIN publico_alvo pa ON p.fk_publico_alvo_codigo = pa.codigo
  WHERE c.descricao = 'Roupa' OR pa.descricao = 'Adulto';

""", run)
# Out:
#         produto  preço_do_produto
# 0       Vestido               599
# 1         Blusa                70
# 2        Camisa                50
# 3       Moletom               150
# 4        Casaco               300
# 5       Jaqueta               250
# 6          Saia                40
# 7         Short                90
# 8       Bermuda               100
# 9         Calça               180
# 10  Calça Jeans               200
# 11         Bota               400
# 12     Sandália                70

# %%
# 3) Consultando o valor total das compras

pd.read_sql_query("""

  SELECT SUM(ci.valor * ci.quantidade) AS Valor_Total_das_Compras
  FROM compra c
  JOIN compra_item ci ON c.codigo = ci.fk_compra_codigo;

""", run)
# Out:
#    valor_total_das_compras
# 0                 181800.0

# %%
# 4) Consultando o estoque de cada produto que possui mais de 100 itens armazenados

pd.read_sql_query("""

  SELECT e.quantidade AS Qtd_em_Estoque, p.descricao AS Produto
  FROM estoque e
  JOIN produto p ON e.fk_produto_codigo = p.codigo
  WHERE e.quantidade > 100;


""", run)
# Out:
#    qtd_em_estoque      produto
# 0             110  Calça Jeans
# 1             120         Bota
# 2             130      Chinelo
# 3             140        Tênis
# 4             150     Sandália

# %%
# 5) Consultando os clientes que realizam pagamentos que não sejam pelo método 'Cartão de Débito'

pd.read_sql_query("""

  SELECT c.nome AS cliente, p.descricao AS metodo_pagamento, s.descricao AS status_pagamento
  FROM pagamento pa
  JOIN cliente c ON pa.fk_compra_codigo IN (SELECT codigo FROM compra WHERE fk_cliente_codigo = c.codigo)
  JOIN metodo_pagamento p ON pa.fk_metodo_pagamento_codigo = p.codigo
  JOIN status_pagamento s ON pa.fk_status_pagamento_codigo = s.codigo
  WHERE NOT p.descricao = 'Cartão de Débito';

""", run)
# Out:
#               cliente   metodo_pagamento status_pagamento
# 0          João Silva  Cartão de Crédito             Pago
# 1      Carlos Pereira                Pix             Pago
# 2            Ana Lima           Dinheiro             Pago
# 3        Bruno Santos  Cartão de Crédito     Em Andamento
# 4       Ricardo Costa                Pix     Em Andamento
# 5    Patricia Almeida           Dinheiro     Em Andamento
# 6     Gustavo Barbosa  Cartão de Crédito         Atrasado
# 7          João Silva                Pix             Pago
# 8         Maria Souza           Dinheiro             Pago
# 9      Carlos Pereira  Cartão de Crédito             Pago
# 10       Bruno Santos                Pix     Em Andamento
# 11  Fernanda Oliveira           Dinheiro     Em Andamento
# 12      Ricardo Costa  Cartão de Crédito     Em Andamento
# 13    Gustavo Barbosa                Pix     Em Andamento
# 14    Juliana Martins           Dinheiro     Em Andamento
# 15         João Silva  Cartão de Crédito         Atrasado
# 16     Carlos Pereira                Pix         Atrasado
# 17           Ana Lima           Dinheiro         Atrasado
# 18       Bruno Santos  Cartão de Crédito             Pago
# 19      Ricardo Costa                Pix             Pago
# 20   Patricia Almeida           Dinheiro             Pago
# 21    Gustavo Barbosa  Cartão de Crédito     Em Andamento
# 22         João Silva                Pix     Em Andamento
# 23        Maria Souza           Dinheiro     Em Andamento
# 24     Carlos Pereira  Cartão de Crédito         Atrasado
# 25       Bruno Santos                Pix         Atrasado

# %%
# 6) Consultando o valor total dos produtos com base em suas quantidades em estoque

pd.read_sql_query("""

  SELECT p.descricao AS produto_nome, e.quantidade AS qtd_em_estoque, (p.preco * e.quantidade) AS valor_total_estoque
  FROM produto p
  JOIN estoque e ON p.codigo = e.fk_produto_codigo;

""", run)
# Out:
#    produto_nome  qtd_em_estoque  valor_total_estoque
# 0       Vestido              50                29950
# 1         Blusa              40                 2800
# 2        Camisa              30                 1500
# 3       Moletom              20                 3000
# 4        Casaco              10                 3000
# 5       Jaqueta              60                15000
# 6          Saia              70                 2800
# 7         Short              80                 7200
# 8       Bermuda              90                 9000
# 9         Calça             100                18000
# 10  Calça Jeans             110                22000
# 11         Bota             120                48000
# 12      Chinelo             130                 2600
# 13        Tênis             140                21000
# 14     Sandália             150                10500

# %%
# 7) Consultando o preço de produtos da categoria 'Roupa' que custam menos de R$100 com um acréscimo de 10%

pd.read_sql_query("""

  SELECT
      descricao AS produto,
      preco * 1.1 AS preco_com_acrescimo_de_10_por_cento
  FROM
      produto
  WHERE
      preco < 100 AND fk_categoria_codigo = 1;

""", run)
# Out:
#   produto  preco_com_acrescimo_de_10_por_cento
# 0   Blusa                                 77.0
# 1  Camisa                                 55.0
# 2    Saia                                 44.0
# 3   Short                                 99.0

# %%
# 8) Consultando o preço de produtos que custam mais de R$100 considerando um desconto de 5%
pd.read_sql_query("""

SELECT
    descricao AS produto,
    preco - (preco * 0.05) AS preco_com_desconto
FROM
    produto
WHERE
    preco > 100;

""", run)
# Out:
#        produto  preco_com_desconto
# 0      Vestido              569.05
# 1      Moletom              142.50
# 2       Casaco              285.00
# 3      Jaqueta              237.50
# 4        Calça              171.00
# 5  Calça Jeans              190.00
# 6         Bota              380.00
# 7        Tênis              142.50

# %%
# 9) Listando clientes inadimplentes e seus CPFs

pd.read_sql_query("""

SELECT
    nome AS cliente_nome,
    cpf AS cliente_cpf
FROM
    cliente
WHERE
    inadimplencia = TRUE;

""", run)
# Out:
#         cliente_nome     cliente_cpf
# 0     Carlos Pereira  333.333.333-33
# 1  Fernanda Oliveira  666.666.666-66

# %%
# 10) Consultando o valor total do estoque (preço * quantidade) para produtos com quantidade acima de 50

pd.read_sql_query("""

SELECT
    descricao AS produto,
    preco * quantidade AS valor_total_em_estoque
FROM
    produto, estoque
WHERE
    produto.codigo = estoque.fk_produto_codigo
    AND quantidade > 50;

""", run)
# Out:
#        produto  valor_total_em_estoque
# 0      Jaqueta                   15000
# 1         Saia                    2800
# 2        Short                    7200
# 3      Bermuda                    9000
# 4        Calça                   18000
# 5  Calça Jeans                   22000
# 6         Bota                   48000
# 7      Chinelo                    2600
# 8        Tênis                   21000
# 9     Sandália                   10500

# %%
# 11) Consultando quantidade em estoque para produtos com uma quantidade entre 20 e 50

pd.read_sql_query("""

  SELECT
      p.descricao AS produto,
      e.quantidade AS estoque_disponivel
  FROM
      produto p, estoque e
  WHERE
      p.codigo = e.fk_produto_codigo
      AND e.quantidade BETWEEN 20 AND 50;

""", run)
# Out:
#    produto  estoque_disponivel
# 0  Vestido                  50
# 1    Blusa                  40
# 2   Camisa                  30
# 3  Moletom                  20

# %% [markdown]
# # **6.4	CONSULTAS QUE USAM OPERADORES LIKE E DATAS (Mínimo 12)**
# - a) Criar outras 5 consultas que envolvam like ou ilike
# - b) Criar uma consulta para cada tipo de função data apresentada

# %%
# 1) Retorna da tabela "produto" as linhas onde o valor na coluna descricao contenha "Vestido"

pd.read_sql_query("""

  SELECT * from produto
  WHERE descricao LIKE 'Vestido'

""", run)
# Out:
#    codigo descricao  preco  fk_cor_codigo  fk_categoria_codigo  \
# 0       1   Vestido    599              1                    1
#
#    fk_tamanho_codigo  fk_publico_alvo_codigo  fk_subcategoria_codigo
# 0                  4                       1                       1

# %%
# 2) Retorna da tabela "cliente" as linhas onde o valor na coluna descricao contenha "111.111.111-11"

pd.read_sql_query("""

SELECT * FROM cliente
WHERE cpf LIKE '111.111.111-11'

""", run)
# Out:
#    codigo        nome             cpf        telefone               email  \
# 0       1  João Silva  111.111.111-11  (11) 999999999  joao@modamania.com
#
#    inadimplencia
# 0          False

# %%
# 3)Retorna da tabela "produto" onde a descrição do produto seja "Chinelo" e a descrição na tabela cor seja "Verde"

pd.read_sql_query("""
  SELECT * FROM produto p
  JOIN cor c ON p.fk_cor_codigo = c.codigo
  WHERE p.descricao LIKE '%Chinelo%' AND c.descricao LIKE '%Verde%';

""", run)
# Out:
#    codigo descricao  preco  fk_cor_codigo  fk_categoria_codigo  \
# 0      13   Chinelo     20              3                    2
#
#    fk_tamanho_codigo  fk_publico_alvo_codigo  fk_subcategoria_codigo  codigo  \
# 0                  5                       2                       2       3
#
#   descricao
# 0     Verde

# %%
# 4)Retorna da tabela "cliente" as linhas onde o valor na coluna nome contenha "jo" como foi feita com "ILIKE"
#     os retornos serão feitos sem diferenciar letras maiusculas e minúsculas

pd.read_sql_query("""

SELECT * FROM cliente c
WHERE nome ILIKE 'jo%'

""", run)
# Out:
#    codigo        nome             cpf        telefone               email  \
# 0       1  João Silva  111.111.111-11  (11) 999999999  joao@modamania.com
#
#    inadimplencia
# 0          False

# %%
# 5) Retorna da tabela "cliente" as linhas onde o valor na coluna nome contenha "silva" como foi feita com "ILIKE"
#     os retornos serão feitos sem diferenciar letras maiusculas e minúsculas

pd.read_sql_query("""

SELECT * FROM cliente c
WHERE nome ILIKE '%silva'

""", run)
# Out:
#    codigo        nome             cpf        telefone               email  \
# 0       1  João Silva  111.111.111-11  (11) 999999999  joao@modamania.com
#
#    inadimplencia
# 0          False

# %%
# 6) Retorna da tabela "cliente" onde o telefone contenha '(11)'

pd.read_sql_query("""

SELECT * FROM cliente c
WHERE telefone LIKE '(11)%'

""", run)
# Out:
#    codigo               nome             cpf        telefone  \
# 0       1         João Silva  111.111.111-11  (11) 999999999
# 1       2        Maria Souza  222.222.222-22  (11) 988888888
# 2       3     Carlos Pereira  333.333.333-33  (11) 977777777
# 3       4           Ana Lima  444.444.444-44  (11) 966666666
# 4       5       Bruno Santos  555.555.555-55  (11) 955555555
# 5       6  Fernanda Oliveira  666.666.666-66  (11) 944444444
# 6       7      Ricardo Costa  777.777.777-77  (11) 933333333
# 7       8   Patricia Almeida  888.888.888-88  (11) 922222222
# 8       9    Gustavo Barbosa  999.999.999-99  (11) 911111111
# 9      10    Juliana Martins  101.010.101-01  (11) 900000000
#
#                     email  inadimplencia
# 0      joao@modamania.com          False
# 1     maria@modamania.com          False
# 2    carlos@modamania.com           True
# 3       ana@modamania.com          False
# 4     bruno@modamania.com          False
# 5  fernanda@modamania.com           True
# 6   ricardo@modamania.com          False
# 7  patricia@modamania.com          False
# 8   gustavo@modamania.com          False
# 9   juliana@modamania.com          False

# %%
# 7) Retorna as compras realizadas no ano atual

pd.read_sql_query("""

  SELECT
      codigo,
      data_compra,
      fk_cliente_codigo
  FROM
      compra
  WHERE
      EXTRACT(YEAR FROM data_compra) = EXTRACT(YEAR FROM CURRENT_DATE);

""", run)
# Out:
#     codigo data_compra  fk_cliente_codigo
# 0       25  2024-01-22                  5
# 1       26  2024-02-10                  6
# 2       27  2024-03-18                  7
# 3       28  2024-04-06                  8
# 4       29  2024-05-25                  9
# 5       30  2024-06-13                 10
# 6       31  2024-07-01                  1
# 7       32  2024-07-25                  2
# 8       33  2024-08-01                  3
# 9       34  2024-08-03                  4
# 10      35  2024-08-04                  5

# %%
# 8) Retorna as compras realizadas no mês atual

pd.read_sql_query("""

  SELECT
      codigo,
      data_compra,
      fk_cliente_codigo
  FROM
      compra
  WHERE
      EXTRACT(MONTH FROM data_compra) = EXTRACT(MONTH FROM CURRENT_DATE)
      AND EXTRACT(YEAR FROM data_compra) = EXTRACT(YEAR FROM CURRENT_DATE);

""", run)
# Out:
#    codigo data_compra  fk_cliente_codigo
# 0      33  2024-08-01                  3
# 1      34  2024-08-03                  4
# 2      35  2024-08-04                  5

# %%
# 9) Clientes que realizaram compras nos últimos 6 meses

pd.read_sql_query("""

  SELECT
      DISTINCT c.nome,
      cl.codigo AS codigo_cliente
  FROM
      cliente c
  JOIN
      compra cl ON c.codigo = cl.fk_cliente_codigo
  WHERE
      cl.data_compra >= (CURRENT_DATE - INTERVAL '6 months');

""", run)
# Out:
#                 nome  codigo_cliente
# 0     Carlos Pereira              33
# 1    Gustavo Barbosa              29
# 2  Fernanda Oliveira              26
# 3         João Silva              31
# 4           Ana Lima              34
# 5        Maria Souza              32
# 6      Ricardo Costa              27
# 7   Patricia Almeida              28
# 8       Bruno Santos              35
# 9    Juliana Martins              30

# %%
# 10) Pagamentos futuros (vencimentos após a data atual)

pd.read_sql_query("""

  SELECT
      codigo,
      data_vencimento,
      valor
  FROM
      pagamento
  WHERE
      data_vencimento > CURRENT_DATE;

""", run)
# Out:
#    codigo data_vencimento   valor
# 0      30      2024-08-28  2950.0
# 1      31      2024-09-09  4600.0
# 2      32      2024-10-22  8100.0
# 3      33      2024-11-05  3400.0
# 4      34      2024-12-16  6100.0
# 5      35      2024-12-29  4200.0

# %%
# 11) Produtos comprados no ano passado

pd.read_sql_query("""

  SELECT
      p.codigo AS codigo_produto,
      p.descricao AS descricao_produto,
      ci.quantidade,
      co.data_compra
  FROM
      compra co
  JOIN
      compra_item ci ON co.codigo = ci.fk_compra_codigo
  JOIN
      produto p ON ci.fk_produto_codigo = p.codigo
  WHERE
      EXTRACT(YEAR FROM co.data_compra) = EXTRACT(YEAR FROM CURRENT_DATE) - 1;

""", run)
# Out:
#     codigo_produto descricao_produto  quantidade data_compra
# 0               13           Chinelo           1  2023-01-12
# 1               14             Tênis           1  2023-02-18
# 2               15          Sandália           1  2023-03-29
# 3                1           Vestido           1  2023-04-04
# 4                2             Blusa           1  2023-05-15
# 5                3            Camisa           1  2023-06-21
# 6                4           Moletom           1  2023-07-11
# 7                5            Casaco           1  2023-08-27
# 8                6           Jaqueta           1  2023-09-09
# 9                7              Saia           1  2023-10-20
# 10               8             Short           1  2023-11-05
# 11               9           Bermuda           1  2023-12-14

# %%
# 12) Compras nos últimos 365 dias e o tempo decorrido desde a compra

pd.read_sql_query("""

  SELECT
      c.codigo AS codigo_compra,
      c.data_compra,
      CURRENT_DATE - c.data_compra AS dias_desde_compra,
      cl.nome AS nome_cliente
  FROM
      compra c
  JOIN
      cliente cl ON c.fk_cliente_codigo = cl.codigo
  WHERE
      (CURRENT_DATE - c.data_compra) <= 365;

""", run)
# Out:
#     codigo_compra data_compra  dias_desde_compra       nome_cliente
# 0              20  2023-08-27                346    Juliana Martins
# 1              21  2023-09-09                333         João Silva
# 2              22  2023-10-20                292        Maria Souza
# 3              23  2023-11-05                276     Carlos Pereira
# 4              24  2023-12-14                237           Ana Lima
# 5              25  2024-01-22                198       Bruno Santos
# 6              26  2024-02-10                179  Fernanda Oliveira
# 7              27  2024-03-18                142      Ricardo Costa
# 8              28  2024-04-06                123   Patricia Almeida
# 9              29  2024-05-25                 74    Gustavo Barbosa
# 10             30  2024-06-13                 55    Juliana Martins
# 11             31  2024-07-01                 37         João Silva
# 12             32  2024-07-25                 13        Maria Souza
# 13             33  2024-08-01                  6     Carlos Pereira
# 14             34  2024-08-03                  4           Ana Lima
# 15             35  2024-08-04                  3       Bruno Santos

# %% [markdown]
# # **6.5	INSTRUÇÕES APLICANDO ATUALIZAÇÃO E EXCLUSÃO DE DADOS (Mínimo 6)**
# -     a) Criar minimo 3 de exclusão
# - b) Criar minimo 3 de atualização

# %%
# 1) Excluindo a cor Roxo

cur.execute("""

  DELETE FROM cor
  WHERE descricao LIKE 'Roxo';

""")

# %%
# 2) Excluindo produtos que possuem cor Branco (Id = 6 na tabela de cores)

cur.execute("""

  DELETE FROM produto
  WHERE fk_cor_codigo = 6;

""")

# %%
# 3) Excluindo um cliente pelo seu Id

cur.execute("""

  DELETE FROM cliente
  WHERE codigo = 5;

""")

# %%
# 4) Acrescentando 10% do valor atual em produtos da categoria "Calçado"

cur.execute("""

  UPDATE produto
  SET preco = preco * 1.10
  WHERE fk_categoria_codigo = (SELECT codigo FROM categoria WHERE descricao = 'Calçado');

""")

# %%
# 5) Atualizando a quantidade de estoque do produto com codigo 10 para 120.

cur.execute("""

  UPDATE estoque
  SET quantidade = 120
  WHERE fk_produto_codigo = 10;

""")

# %%
# 6) Atualizando o status de pagamento da compra com codigo 5 para "Pago"

cur.execute("""

  UPDATE pagamento
  SET fk_status_pagamento_codigo = 1
  WHERE codigo = 5;

""")

# %% [markdown]
# # **6.6	CONSULTAS COM INNER JOIN E ORDER BY (Mínimo 6)**
# - a) Uma junção que envolva todas as tabelas possuindo no mínimo 2 registros no resultado
# - b) Outras junções que o grupo considere como sendo as de principal importância para o trabalho

# %%
# 1) Consulta irá trazer detalhes completos de cada compra, incluindo informações do cliente, produto, estoque, e pagamento.
# Esta é a junção que envolve todas as tabelas

pd.read_sql_query("""

  SELECT
      cliente.nome AS nome_cliente,
      compra.data_compra,
      produto.descricao AS descricao_produto,
      estoque.quantidade AS quantidade_estoque,
      cor.descricao AS cor_produto,
      categoria.descricao AS categoria_produto,
      tamanho.descricao AS tamanho_produto,
      publico_alvo.descricao AS publico_alvo_produto,
      subcategoria.descricao AS subcategoria_produto,
      compra_item.valor AS valor_compra_item,
      compra_item.quantidade AS quantidade_compra_item,
      metodo_pagamento.descricao AS metodo_pagamento,
      status_pagamento.descricao AS status_pagamento,
      pagamento.data_pagamento,
      pagamento.data_vencimento,
      pagamento.valor AS valor_pagamento
  FROM
      cliente
  INNER JOIN compra ON cliente.codigo = compra.fk_cliente_codigo
  INNER JOIN compra_item ON compra.codigo = compra_item.fk_compra_codigo
  INNER JOIN produto ON compra_item.fk_produto_codigo = produto.codigo
  INNER JOIN cor ON produto.fk_cor_codigo = cor.codigo
  INNER JOIN categoria ON produto.fk_categoria_codigo = categoria.codigo
  INNER JOIN tamanho ON produto.fk_tamanho_codigo = tamanho.codigo
  INNER JOIN publico_alvo ON produto.fk_publico_alvo_codigo = publico_alvo.codigo
  INNER JOIN subcategoria ON produto.fk_subcategoria_codigo = subcategoria.codigo
  INNER JOIN estoque ON produto.codigo = estoque.fk_produto_codigo
  INNER JOIN pagamento ON compra.codigo = pagamento.fk_compra_codigo
  INNER JOIN metodo_pagamento ON pagamento.fk_metodo_pagamento_codigo = metodo_pagamento.codigo
  INNER JOIN status_pagamento ON pagamento.fk_status_pagamento_codigo = status_pagamento.codigo
  ORDER BY compra.data_compra DESC, cliente.nome ASC

""", run)
# Out:
#          nome_cliente data_compra descricao_produto  quantidade_estoque  \
# 0     Juliana Martins  2024-06-13          Sandália                 150
# 1     Gustavo Barbosa  2024-05-25             Tênis                 140
# 2    Patricia Almeida  2024-04-06           Chinelo                 130
# 3       Ricardo Costa  2024-03-18              Bota                 120
# 4   Fernanda Oliveira  2024-02-10       Calça Jeans                 110
# 5        Bruno Santos  2024-01-22             Calça                 100
# 6            Ana Lima  2023-12-14           Bermuda                  90
# 7      Carlos Pereira  2023-11-05             Short                  80
# 8         Maria Souza  2023-10-20              Saia                  70
# 9          João Silva  2023-09-09           Jaqueta                  60
# 10    Juliana Martins  2023-08-27            Casaco                  10
# 11    Gustavo Barbosa  2023-07-11           Moletom                  20
# 12   Patricia Almeida  2023-06-21            Camisa                  30
# 13      Ricardo Costa  2023-05-15             Blusa                  40
# 14  Fernanda Oliveira  2023-04-04           Vestido                  50
# 15       Bruno Santos  2023-03-29          Sandália                 150
# 16           Ana Lima  2023-02-18             Tênis                 140
# 17     Carlos Pereira  2023-01-12           Chinelo                 130
# 18        Maria Souza  2022-12-31              Bota                 120
# 19         João Silva  2022-11-24       Calça Jeans                 110
# 20    Juliana Martins  2022-10-13             Calça                 100
# 21    Gustavo Barbosa  2022-09-08           Bermuda                  90
# 22   Patricia Almeida  2022-08-19             Short                  80
# 23      Ricardo Costa  2022-07-22              Saia                  70
# 24  Fernanda Oliveira  2022-06-30           Jaqueta                  60
# 25       Bruno Santos  2022-05-10            Casaco                  10
# 26       Bruno Santos  2022-05-10            Casaco                  10
# 27           Ana Lima  2022-04-25           Moletom                  20
# 28           Ana Lima  2022-04-25           Moletom                  20
# 29     Carlos Pereira  2022-03-20            Camisa                  30
# 30     Carlos Pereira  2022-03-20            Camisa                  30
# 31        Maria Souza  2022-02-15             Blusa                  40
# 32        Maria Souza  2022-02-15             Blusa                  40
# 33         João Silva  2022-01-05           Vestido                  50
# 34         João Silva  2022-01-05           Vestido                  50
#
#    cor_produto categoria_produto tamanho_produto publico_alvo_produto  \
# 0        Preto           Calçado        Infantil               Adulto
# 1      Amarelo           Calçado        Infantil             Infantil
# 2        Verde           Calçado              GG             Infantil
# 3         Azul           Calçado        Infantil               Adulto
# 4     Vermelho             Roupa               P             Infantil
# 5         Bege             Roupa               P             Infantil
# 6       Marrom             Roupa               M             Infantil
# 7         Rosa             Roupa               M             Infantil
# 8        Cinza             Roupa              GG               Adulto
# 9       Branco             Roupa               M             Infantil
# 10       Preto             Roupa               G               Adulto
# 11     Amarelo             Roupa               G             Infantil
# 12       Verde             Roupa              PP               Adulto
# 13        Azul             Roupa               P               Adulto
# 14    Vermelho             Roupa               G               Adulto
# 15       Preto           Calçado        Infantil               Adulto
# 16     Amarelo           Calçado        Infantil             Infantil
# 17       Verde           Calçado              GG             Infantil
# 18        Azul           Calçado        Infantil               Adulto
# 19    Vermelho             Roupa               P             Infantil
# 20        Bege             Roupa               P             Infantil
# 21      Marrom             Roupa               M             Infantil
# 22        Rosa             Roupa               M             Infantil
# 23       Cinza             Roupa              GG               Adulto
# 24      Branco             Roupa               M             Infantil
# 25       Preto             Roupa               G               Adulto
# 26       Preto             Roupa               G               Adulto
# 27     Amarelo             Roupa               G             Infantil
# 28     Amarelo             Roupa               G             Infantil
# 29       Verde             Roupa              PP               Adulto
# 30       Verde             Roupa              PP               Adulto
# 31        Azul             Roupa               P               Adulto
# 32        Azul             Roupa               P               Adulto
# 33    Vermelho             Roupa               G               Adulto
# 34    Vermelho             Roupa               G               Adulto
#
#    subcategoria_produto  valor_compra_item  quantidade_compra_item  \
# 0              Feminino             2950.0                       1
# 1              Feminino             3150.0                       1
# 2             Masculino             2350.0                       1
# 3             Masculino             5550.0                       1
# 4             Masculino             4550.0                       1
# 5             Masculino             7050.0                       1
# 6             Masculino             1550.0                       1
# 7             Masculino            12100.0                       1
# 8              Feminino            10050.0                       1
# 9              Feminino             2800.0                       1
# 10             Feminino             4100.0                       1
# 11            Masculino             6200.0                       1
# 12            Masculino             3300.0                       1
# 13             Feminino             8200.0                       1
# 14             Feminino             4700.0                       1
# 15             Feminino             2900.0                       1
# 16             Feminino             3100.0                       1
# 17            Masculino             2300.0                       1
# 18            Masculino             5500.0                       1
# 19            Masculino             4500.0                       1
# 20            Masculino             7000.0                       1
# 21            Masculino             1500.0                       1
# 22            Masculino            12000.0                       1
# 23             Feminino            10000.0                       1
# 24             Feminino             2000.0                       1
# 25             Feminino             4200.0                       1
# 26             Feminino             4000.0                       1
# 27            Masculino             6100.0                       1
# 28            Masculino             6000.0                       1
# 29            Masculino             3000.0                       1
# 30            Masculino             3400.0                       1
# 31             Feminino             8100.0                       1
# 32             Feminino             8000.0                       1
# 33             Feminino             5000.0                       1
# 34             Feminino             4600.0                       1
#
#      metodo_pagamento status_pagamento data_pagamento data_vencimento  \
# 0    Cartão de Débito     Em Andamento     2024-08-28      2024-08-28
# 1   Cartão de Crédito     Em Andamento     2024-07-21      2024-07-21
# 2            Dinheiro             Pago     2024-06-06      2024-06-06
# 3                 Pix             Pago     2024-05-11      2024-05-11
# 4    Cartão de Débito             Pago     2024-04-25      2024-04-25
# 5   Cartão de Crédito             Pago     2024-03-18      2024-03-18
# 6            Dinheiro         Atrasado     2024-02-05      2024-02-05
# 7                 Pix         Atrasado     2024-01-16      2024-01-16
# 8    Cartão de Débito         Atrasado     2023-12-07      2023-12-07
# 9   Cartão de Crédito         Atrasado     2023-11-30      2023-11-30
# 10           Dinheiro     Em Andamento     2023-10-08      2023-10-08
# 11                Pix     Em Andamento     2023-09-23      2023-09-23
# 12   Cartão de Débito     Em Andamento     2023-08-14      2023-08-14
# 13  Cartão de Crédito     Em Andamento     2023-07-19      2023-07-19
# 14           Dinheiro     Em Andamento     2023-06-27      2023-06-27
# 15                Pix     Em Andamento     2023-05-11      2023-05-11
# 16   Cartão de Débito             Pago     2023-04-18      2023-04-18
# 17  Cartão de Crédito             Pago     2023-03-05      2023-03-05
# 18           Dinheiro             Pago     2023-02-25      2023-02-25
# 19                Pix             Pago     2023-01-10      2023-01-10
# 20   Cartão de Débito         Atrasado     2022-11-14      2022-11-14
# 21  Cartão de Crédito         Atrasado     2022-10-21      2022-10-21
# 22           Dinheiro     Em Andamento     2022-09-30      2022-09-30
# 23                Pix     Em Andamento     2022-08-15      2022-08-15
# 24   Cartão de Débito     Em Andamento     2022-07-07      2022-07-07
# 25  Cartão de Crédito     Em Andamento     2022-06-11      2022-06-11
# 26  Cartão de Crédito     Em Andamento     2022-06-11      2022-06-11
# 27           Dinheiro             Pago     2022-05-22      2022-05-22
# 28           Dinheiro             Pago     2022-05-22      2022-05-22
# 29                Pix             Pago     2022-04-19      2022-04-19
# 30                Pix             Pago     2022-04-19      2022-04-19
# 31   Cartão de Débito             Pago     2022-03-12      2022-03-12
# 32   Cartão de Débito             Pago     2022-03-12      2022-03-12
# 33  Cartão de Crédito             Pago     2022-02-05      2022-02-05
# 34  Cartão de Crédito             Pago     2022-02-05      2022-02-05
#
#     valor_pagamento
# 0            2950.0
# 1            3150.0
# 2            2350.0
# 3            5550.0
# 4            4550.0
# 5            7050.0
# 6            1550.0
# 7           12100.0
# 8           10050.0
# 9            2800.0
# 10           4100.0
# 11           6200.0
# 12           3300.0
# 13           8200.0
# 14           4700.0
# 15           2900.0
# 16           3100.0
# 17           2300.0
# 18           5500.0
# 19           4500.0
# 20           7000.0
# 21           1500.0
# 22          12000.0
# 23          10000.0
# 24           2000.0
# 25           4000.0
# 26           4000.0
# 27           6000.0
# 28           6000.0
# 29           3000.0
# 30           3000.0
# 31           8000.0
# 32           8000.0
# 33           5000.0
# 34           5000.0

# %%
# 2) Consulta de compras mostrando detalhes dos clientes e produtos envolvidos.

pd.read_sql_query("""

  SELECT
      cliente.nome AS nome_cliente,
      cliente.email AS email_cliente,
      compra.data_compra,
      produto.descricao AS descricao_produto,
      produto.preco AS preco_produto,
      compra_item.quantidade AS quantidade_comprada
  FROM
      cliente
  INNER JOIN compra ON cliente.codigo = compra.fk_cliente_codigo
  INNER JOIN compra_item ON compra.codigo = compra_item.fk_compra_codigo
  INNER JOIN produto ON compra_item.fk_produto_codigo = produto.codigo
  ORDER BY compra.data_compra DESC, cliente.nome ASC

""", run)
# Out:
#          nome_cliente           email_cliente data_compra descricao_produto  \
# 0     Juliana Martins   juliana@modamania.com  2024-06-13          Sandália
# 1     Gustavo Barbosa   gustavo@modamania.com  2024-05-25             Tênis
# 2    Patricia Almeida  patricia@modamania.com  2024-04-06           Chinelo
# 3       Ricardo Costa   ricardo@modamania.com  2024-03-18              Bota
# 4   Fernanda Oliveira  fernanda@modamania.com  2024-02-10       Calça Jeans
# 5        Bruno Santos     bruno@modamania.com  2024-01-22             Calça
# 6            Ana Lima       ana@modamania.com  2023-12-14           Bermuda
# 7      Carlos Pereira    carlos@modamania.com  2023-11-05             Short
# 8         Maria Souza     maria@modamania.com  2023-10-20              Saia
# 9          João Silva      joao@modamania.com  2023-09-09           Jaqueta
# 10    Juliana Martins   juliana@modamania.com  2023-08-27            Casaco
# 11    Gustavo Barbosa   gustavo@modamania.com  2023-07-11           Moletom
# 12   Patricia Almeida  patricia@modamania.com  2023-06-21            Camisa
# 13      Ricardo Costa   ricardo@modamania.com  2023-05-15             Blusa
# 14  Fernanda Oliveira  fernanda@modamania.com  2023-04-04           Vestido
# 15       Bruno Santos     bruno@modamania.com  2023-03-29          Sandália
# 16           Ana Lima       ana@modamania.com  2023-02-18             Tênis
# 17     Carlos Pereira    carlos@modamania.com  2023-01-12           Chinelo
# 18        Maria Souza     maria@modamania.com  2022-12-31              Bota
# 19         João Silva      joao@modamania.com  2022-11-24       Calça Jeans
# 20    Juliana Martins   juliana@modamania.com  2022-10-13             Calça
# 21    Gustavo Barbosa   gustavo@modamania.com  2022-09-08           Bermuda
# 22   Patricia Almeida  patricia@modamania.com  2022-08-19             Short
# 23      Ricardo Costa   ricardo@modamania.com  2022-07-22              Saia
# 24  Fernanda Oliveira  fernanda@modamania.com  2022-06-30           Jaqueta
# 25       Bruno Santos     bruno@modamania.com  2022-05-10            Casaco
# 26       Bruno Santos     bruno@modamania.com  2022-05-10            Casaco
# 27           Ana Lima       ana@modamania.com  2022-04-25           Moletom
# 28           Ana Lima       ana@modamania.com  2022-04-25           Moletom
# 29     Carlos Pereira    carlos@modamania.com  2022-03-20            Camisa
# 30     Carlos Pereira    carlos@modamania.com  2022-03-20            Camisa
# 31        Maria Souza     maria@modamania.com  2022-02-15             Blusa
# 32        Maria Souza     maria@modamania.com  2022-02-15             Blusa
# 33         João Silva      joao@modamania.com  2022-01-05           Vestido
# 34         João Silva      joao@modamania.com  2022-01-05           Vestido
#
#     preco_produto  quantidade_comprada
# 0              70                    1
# 1             150                    1
# 2              20                    1
# 3             400                    1
# 4             200                    1
# 5             180                    1
# 6             100                    1
# 7              90                    1
# 8              40                    1
# 9             250                    1
# 10            300                    1
# 11            150                    1
# 12             50                    1
# 13             70                    1
# 14            599                    1
# 15             70                    1
# 16            150                    1
# 17             20                    1
# 18            400                    1
# 19            200                    1
# 20            180                    1
# 21            100                    1
# 22             90                    1
# 23             40                    1
# 24            250                    1
# 25            300                    1
# 26            300                    1
# 27            150                    1
# 28            150                    1
# 29             50                    1
# 30             50                    1
# 31             70                    1
# 32             70                    1
# 33            599                    1
# 34            599                    1

# %%
# 3) Consulta para listar clientes que estão inadimplentes, incluindo detalhes de pagamento e status.

pd.read_sql_query("""

  SELECT
      cliente.nome AS nome_cliente,
      cliente.email AS email_cliente,
      pagamento.valor AS valor_pagamento,
      pagamento.data_vencimento,
      status_pagamento.descricao AS status_pagamento
  FROM
      cliente
  INNER JOIN compra ON cliente.codigo = compra.fk_cliente_codigo
  INNER JOIN pagamento ON compra.codigo = pagamento.fk_compra_codigo
  INNER JOIN status_pagamento ON pagamento.fk_status_pagamento_codigo = status_pagamento.codigo
  WHERE cliente.inadimplencia = TRUE
  ORDER BY pagamento.data_vencimento ASC, cliente.nome ASC;

""", run)
# Out:
#         nome_cliente           email_cliente  valor_pagamento data_vencimento  \
# 0     Carlos Pereira    carlos@modamania.com           3000.0      2022-04-19
# 1  Fernanda Oliveira  fernanda@modamania.com           2000.0      2022-07-07
# 2     Carlos Pereira    carlos@modamania.com           2300.0      2023-03-05
# 3  Fernanda Oliveira  fernanda@modamania.com           4700.0      2023-06-27
# 4     Carlos Pereira    carlos@modamania.com          12100.0      2024-01-16
# 5  Fernanda Oliveira  fernanda@modamania.com           4550.0      2024-04-25
# 6     Carlos Pereira    carlos@modamania.com           3400.0      2024-11-05
#
#   status_pagamento
# 0             Pago
# 1     Em Andamento
# 2             Pago
# 3     Em Andamento
# 4         Atrasado
# 5             Pago
# 6         Atrasado

# %%
# 4) Consulta que retorna produtos que têm um estoque baixo (menos de 60 unidades)

pd.read_sql_query("""

  SELECT
      produto.descricao AS descricao_produto,
      estoque.quantidade AS quantidade_estoque,
      cor.descricao AS cor_produto,
      categoria.descricao AS categoria_produto,
      tamanho.descricao AS tamanho_produto
  FROM
      produto
  INNER JOIN estoque ON produto.codigo = estoque.fk_produto_codigo
  INNER JOIN cor ON produto.fk_cor_codigo = cor.codigo
  INNER JOIN categoria ON produto.fk_categoria_codigo = categoria.codigo
  INNER JOIN tamanho ON produto.fk_tamanho_codigo = tamanho.codigo
  WHERE estoque.quantidade < 60
  ORDER BY estoque.quantidade ASC, produto.descricao ASC;

""", run)
# Out:
#   descricao_produto  quantidade_estoque cor_produto categoria_produto  \
# 0            Casaco                  10       Preto             Roupa
# 1           Moletom                  20     Amarelo             Roupa
# 2            Camisa                  30       Verde             Roupa
# 3             Blusa                  40        Azul             Roupa
# 4           Vestido                  50    Vermelho             Roupa
#
#   tamanho_produto
# 0               G
# 1               G
# 2              PP
# 3               P
# 4               G

# %%
# 5) Consulta para ver a quantidade de compras e o valor total por método de pagamento.

pd.read_sql_query("""

    SELECT
        metodo_pagamento.descricao AS metodo_pagamento,
        COUNT(compra.codigo) AS quantidade_compras,
        SUM(pagamento.valor) AS valor_total
    FROM
        compra
    INNER JOIN pagamento ON compra.codigo = pagamento.fk_compra_codigo
    INNER JOIN metodo_pagamento ON pagamento.fk_metodo_pagamento_codigo = metodo_pagamento.codigo
    GROUP BY metodo_pagamento.descricao
    ORDER BY valor_total DESC;

""", run)
# Out:
#     metodo_pagamento  quantidade_compras  valor_total
# 0                Pix                   9      53050.0
# 1   Cartão de Débito                   9      47050.0
# 2           Dinheiro                   8      44300.0
# 3  Cartão de Crédito                   9      37400.0

# %%
# 6) Consulta para listar os produtos mais vendidos, com a quantidade total vendida.

pd.read_sql_query("""

  SELECT
      produto.descricao AS descricao_produto,
      SUM(compra_item.quantidade) AS quantidade_vendida,
      categoria.descricao AS categoria_produto,
      cor.descricao AS cor_produto,
      tamanho.descricao AS tamanho_produto
  FROM
      produto
  INNER JOIN compra_item ON produto.codigo = compra_item.fk_produto_codigo
  INNER JOIN categoria ON produto.fk_categoria_codigo = categoria.codigo
  INNER JOIN cor ON produto.fk_cor_codigo = cor.codigo
  INNER JOIN tamanho ON produto.fk_tamanho_codigo = tamanho.codigo
  GROUP BY produto.descricao, categoria.descricao, cor.descricao, tamanho.descricao
  ORDER BY quantidade_vendida DESC, produto.descricao ASC

""", run)
# Out:
#    descricao_produto  quantidade_vendida categoria_produto cor_produto  \
# 0              Blusa                   3             Roupa        Azul
# 1             Camisa                   3             Roupa       Verde
# 2             Casaco                   3             Roupa       Preto
# 3            Moletom                   3             Roupa     Amarelo
# 4            Vestido                   3             Roupa    Vermelho
# 5            Bermuda                   2             Roupa      Marrom
# 6               Bota                   2           Calçado        Azul
# 7              Calça                   2             Roupa        Bege
# 8        Calça Jeans                   2             Roupa    Vermelho
# 9            Chinelo                   2           Calçado       Verde
# 10           Jaqueta                   2             Roupa      Branco
# 11              Saia                   2             Roupa       Cinza
# 12          Sandália                   2           Calçado       Preto
# 13             Short                   2             Roupa        Rosa
# 14             Tênis                   2           Calçado     Amarelo
#
#    tamanho_produto
# 0                P
# 1               PP
# 2                G
# 3                G
# 4                G
# 5                M
# 6         Infantil
# 7                P
# 8                P
# 9               GG
# 10               M
# 11              GG
# 12        Infantil
# 13               M
# 14        Infantil

# %% [markdown]
# # **6.7	CONSULTAS COM GROUP BY E FUNÇÕES DE AGRUPAMENTO (Mínimo 6)**
# - a) Criar minimo 2 envolvendo algum tipo de junção

# %%
# 1) Calcula o valor total de uma compra

pd.read_sql_query("""

  SELECT fk_compra_codigo, SUM(valor) AS total_valor
  FROM compra_item
  GROUP BY fk_compra_codigo
  ORDER BY total_valor;

""", run)
# Out:
#     fk_compra_codigo  total_valor
# 0                  9       1500.0
# 1                 24       1550.0
# 2                  6       2000.0
# 3                 13       2300.0
# 4                 28       2350.0
# 5                 21       2800.0
# 6                 15       2900.0
# 7                 30       2950.0
# 8                 14       3100.0
# 9                 29       3150.0
# 10                18       3300.0
# 11                20       4100.0
# 12                11       4500.0
# 13                26       4550.0
# 14                16       4700.0
# 15                12       5500.0
# 16                27       5550.0
# 17                19       6200.0
# 18                 3       6400.0
# 19                10       7000.0
# 20                25       7050.0
# 21                 5       8200.0
# 22                17       8200.0
# 23                 1       9600.0
# 24                 7      10000.0
# 25                22      10050.0
# 26                 8      12000.0
# 27                 4      12100.0
# 28                23      12100.0
# 29                 2      16100.0

# %%
# 2) Consultando a soma do preço dos produtos de cada cor

pd.read_sql_query("""

  SELECT
      c.descricao AS Cor_Do_Produto,
      SUM(p.preco) AS Soma_Do_Preços_Por_Cor
  FROM
      produto p
  JOIN
      cor c ON p.fk_cor_codigo = c.codigo
  GROUP BY
      c.descricao
  ORDER BY
      Soma_Do_Preços_Por_Cor;
""", run)
# Out:
#   cor_do_produto  soma_do_preços_por_cor
# 0          Cinza                      40
# 1          Verde                      70
# 2           Rosa                      90
# 3         Marrom                     100
# 4           Bege                     180
# 5         Branco                     250
# 6        Amarelo                     300
# 7          Preto                     370
# 8           Azul                     470
# 9       Vermelho                     799

# %%
# 3) Quantidade total de produtos vendidos por categoria

pd.read_sql_query("""

  SELECT c.descricao AS categoria, SUM(ci.quantidade) AS total_vendido
  FROM compra_item ci
  JOIN produto p ON ci.fk_produto_codigo = p.codigo
  JOIN categoria c ON p.fk_categoria_codigo = c.codigo
  GROUP BY c.descricao
  ORDER BY total_vendido;

""", run)
# Out:
#   categoria  total_vendido
# 0   Calçado              8
# 1     Roupa             27

# %%
# 4) Média de valor gasto por compra por método de pagamento

pd.read_sql_query("""

  SELECT mp.descricao AS metodo_pagamento, AVG(pag.valor) AS media_gasto
  FROM pagamento pag
  JOIN metodo_pagamento mp ON pag.fk_metodo_pagamento_codigo = mp.codigo
  GROUP BY mp.descricao
  ORDER BY media_gasto;

""", run)
# Out:
#     metodo_pagamento  media_gasto
# 0  Cartão de Crédito  4155.555556
# 1   Cartão de Débito  5227.777778
# 2           Dinheiro  5537.500000
# 3                Pix  5894.444444

# %%
# 5) Valor total das compras por cliente

pd.read_sql_query("""

  SELECT cl.nome AS cliente, SUM(ci.valor) AS total_gasto
  FROM compra_item ci
  JOIN compra co ON ci.fk_compra_codigo = co.codigo
  JOIN cliente cl ON co.fk_cliente_codigo = cl.codigo
  GROUP BY cl.nome;

""", run)
# Out:
#              cliente  total_gasto
# 0     Carlos Pereira      20800.0
# 1    Gustavo Barbosa      10850.0
# 2   Patricia Almeida      17650.0
# 3      Ricardo Costa      23750.0
# 4       Bruno Santos      18150.0
# 5        Maria Souza      31650.0
# 6           Ana Lima      16750.0
# 7         João Silva      16900.0
# 8    Juliana Martins      14050.0
# 9  Fernanda Oliveira      11250.0

# %%
# 6) Valor total de compras e quantidade de itens vendidos por produto

pd.read_sql_query("""

  SELECT p.descricao AS produto, SUM(ci.valor) AS valor_total, SUM(ci.quantidade) AS quantidade_total
  FROM compra_item ci
  JOIN produto p ON ci.fk_produto_codigo = p.codigo
  GROUP BY p.descricao;

""", run)
# Out:
#         produto  valor_total  quantidade_total
# 0       Jaqueta       4800.0                 2
# 1         Calça      14050.0                 2
# 2   Calça Jeans       9050.0                 2
# 3         Tênis       6250.0                 2
# 4          Bota      11050.0                 2
# 5        Camisa       9700.0                 3
# 6          Saia      20050.0                 2
# 7         Blusa      24300.0                 3
# 8       Bermuda       3050.0                 2
# 9         Short      24100.0                 2
# 10      Moletom      18300.0                 3
# 11      Chinelo       4650.0                 2
# 12     Sandália       5850.0                 2
# 13      Vestido      14300.0                 3
# 14       Casaco      12300.0                 3

# %% [markdown]
# # **6.8	CONSULTAS COM LEFT, RIGHT E FULL JOIN (Mínimo 4)**
# - a) Criar minimo 1 de cada tipo

# %%
# 1) Consulta retorna todos os produtos e suas respectivas cores.

pd.read_sql_query("""

  SELECT
      produto.codigo AS produto_codigo,
      produto.descricao AS produto_descricao,
      cor.descricao AS cor_descricao
  FROM
      produto
  LEFT JOIN
      cor ON produto.fk_cor_codigo = cor.codigo;

""", run)
# Out:
#     produto_codigo produto_descricao cor_descricao
# 0                1           Vestido      Vermelho
# 1                2             Blusa          Azul
# 2                3            Camisa         Verde
# 3                4           Moletom       Amarelo
# 4                5            Casaco         Preto
# 5                6           Jaqueta        Branco
# 6                7              Saia         Cinza
# 7                8             Short          Rosa
# 8                9           Bermuda        Marrom
# 9               10             Calça          Bege
# 10              11       Calça Jeans      Vermelho
# 11              12              Bota          Azul
# 12              13           Chinelo         Verde
# 13              14             Tênis       Amarelo
# 14              15          Sandália         Preto

# %%
# 2) Consulta exibe todos os métodos de pagamento, incluindo aqueles que não têm compras associadas.

pd.read_sql_query("""

  SELECT
      metodo_pagamento.descricao AS metodo_pagamento,
      compra.codigo AS compra_codigo,
      compra.data_compra
  FROM
      compra
  RIGHT JOIN
      metodo_pagamento ON compra.codigo = metodo_pagamento.codigo;

""", run)
# Out:
#     metodo_pagamento  compra_codigo data_compra
# 0  Cartão de Crédito              1  2022-01-05
# 1   Cartão de Débito              2  2022-02-15
# 2                Pix              3  2022-03-20
# 3           Dinheiro              4  2022-04-25

# %%
# 3) Consulta combina clientes e compras, mostrando todos os clientes, todas as compras, e as associações entre eles.

pd.read_sql_query("""

  SELECT
      cliente.codigo AS cliente_codigo,
      cliente.nome AS cliente_nome,
      compra.codigo AS compra_codigo,
      compra.data_compra
  FROM
      cliente
  FULL JOIN
      compra ON cliente.codigo = compra.fk_cliente_codigo;

""", run)
# Out:
#     cliente_codigo       cliente_nome  compra_codigo data_compra
# 0                1         João Silva              1  2022-01-05
# 1                2        Maria Souza              2  2022-02-15
# 2                3     Carlos Pereira              3  2022-03-20
# 3                4           Ana Lima              4  2022-04-25
# 4                5       Bruno Santos              5  2022-05-10
# 5                6  Fernanda Oliveira              6  2022-06-30
# 6                7      Ricardo Costa              7  2022-07-22
# 7                8   Patricia Almeida              8  2022-08-19
# 8                9    Gustavo Barbosa              9  2022-09-08
# 9               10    Juliana Martins             10  2022-10-13
# 10               1         João Silva             11  2022-11-24
# 11               2        Maria Souza             12  2022-12-31
# 12               3     Carlos Pereira             13  2023-01-12
# 13               4           Ana Lima             14  2023-02-18
# 14               5       Bruno Santos             15  2023-03-29
# 15               6  Fernanda Oliveira             16  2023-04-04
# 16               7      Ricardo Costa             17  2023-05-15
# 17               8   Patricia Almeida             18  2023-06-21
# 18               9    Gustavo Barbosa             19  2023-07-11
# 19              10    Juliana Martins             20  2023-08-27
# 20               1         João Silva             21  2023-09-09
# 21               2        Maria Souza             22  2023-10-20
# 22               3     Carlos Pereira             23  2023-11-05
# 23               4           Ana Lima             24  2023-12-14
# 24               5       Bruno Santos             25  2024-01-22
# 25               6  Fernanda Oliveira             26  2024-02-10
# 26               7      Ricardo Costa             27  2024-03-18
# 27               8   Patricia Almeida             28  2024-04-06
# 28               9    Gustavo Barbosa             29  2024-05-25
# 29              10    Juliana Martins             30  2024-06-13
# 30               1         João Silva             31  2024-07-01
# 31               2        Maria Souza             32  2024-07-25
# 32               3     Carlos Pereira             33  2024-08-01
# 33               4           Ana Lima             34  2024-08-03
# 34               5       Bruno Santos             35  2024-08-04

# %%
# 4) Consulta todos os produtos e suas subcategorias, e mostra a quantidade em estoque, se houver.

pd.read_sql_query("""

  SELECT
      produto.codigo AS produto_codigo,
      produto.descricao AS produto_descricao,
      estoque.quantidade AS quantidade_estoque,
      subcategoria.descricao AS subcategoria_descricao
  FROM
      produto
  LEFT JOIN
      estoque ON produto.codigo = estoque.fk_produto_codigo
  RIGHT JOIN
      subcategoria ON produto.fk_subcategoria_codigo = subcategoria.codigo;

""",run)
# Out:
#     produto_codigo produto_descricao  quantidade_estoque  \
# 0                1           Vestido                  50
# 1                2             Blusa                  40
# 2                3            Camisa                  30
# 3                4           Moletom                  20
# 4                5            Casaco                  10
# 5                6           Jaqueta                  60
# 6                7              Saia                  70
# 7                8             Short                  80
# 8                9           Bermuda                  90
# 9               10             Calça                 100
# 10              11       Calça Jeans                 110
# 11              12              Bota                 120
# 12              13           Chinelo                 130
# 13              14             Tênis                 140
# 14              15          Sandália                 150
#
#    subcategoria_descricao
# 0                Feminino
# 1                Feminino
# 2               Masculino
# 3               Masculino
# 4                Feminino
# 5                Feminino
# 6                Feminino
# 7               Masculino
# 8               Masculino
# 9               Masculino
# 10              Masculino
# 11              Masculino
# 12              Masculino
# 13               Feminino
# 14               Feminino

# %% [markdown]
# # **6.9	CONSULTAS COM SELF JOIN E VIEW (Mínimo 6)**
# - a) Uma junção que envolva Self Join (caso não ocorra na base justificar e substituir por uma view)
# - b) Outras junções com views que o grupo considere como sendo de relevante importância para o trabalho

# %%
# 1) Compras realizadas pelo mesmo cliente em datas diferentes

pd.read_sql_query("""

  SELECT
      c1.codigo AS compra1_codigo,
      c1.data_compra AS compra1_data,
      c2.codigo AS compra2_codigo,
      c2.data_compra AS compra2_data,
      cliente.nome AS cliente_nome
  FROM
      compra c1
  JOIN
      compra c2 ON c1.fk_cliente_codigo = c2.fk_cliente_codigo
              AND c1.data_compra <> c2.data_compra
  JOIN
      cliente ON c1.fk_cliente_codigo = cliente.codigo
  WHERE
      c1.codigo < c2.codigo;

""", run)
# Out:
#     compra1_codigo compra1_data  compra2_codigo compra2_data  \
# 0               21   2023-09-09              31   2024-07-01
# 1                1   2022-01-05              21   2023-09-09
# 2                1   2022-01-05              11   2022-11-24
# 3                1   2022-01-05              31   2024-07-01
# 4               11   2022-11-24              21   2023-09-09
# 5               11   2022-11-24              31   2024-07-01
# 6               22   2023-10-20              32   2024-07-25
# 7               12   2022-12-31              22   2023-10-20
# 8               12   2022-12-31              32   2024-07-25
# 9                2   2022-02-15              22   2023-10-20
# 10               2   2022-02-15              12   2022-12-31
# 11               2   2022-02-15              32   2024-07-25
# 12              23   2023-11-05              33   2024-08-01
# 13              13   2023-01-12              23   2023-11-05
# 14              13   2023-01-12              33   2024-08-01
# 15               3   2022-03-20              23   2023-11-05
# 16               3   2022-03-20              33   2024-08-01
# 17               3   2022-03-20              13   2023-01-12
# 18              24   2023-12-14              34   2024-08-03
# 19              14   2023-02-18              24   2023-12-14
# 20              14   2023-02-18              34   2024-08-03
# 21               4   2022-04-25              24   2023-12-14
# 22               4   2022-04-25              14   2023-02-18
# 23               4   2022-04-25              34   2024-08-03
# 24               5   2022-05-10              35   2024-08-04
# 25               5   2022-05-10              15   2023-03-29
# 26               5   2022-05-10              25   2024-01-22
# 27              15   2023-03-29              35   2024-08-04
# 28              15   2023-03-29              25   2024-01-22
# 29              25   2024-01-22              35   2024-08-04
# 30              16   2023-04-04              26   2024-02-10
# 31               6   2022-06-30              16   2023-04-04
# 32               6   2022-06-30              26   2024-02-10
# 33               7   2022-07-22              17   2023-05-15
# 34               7   2022-07-22              27   2024-03-18
# 35              17   2023-05-15              27   2024-03-18
# 36              18   2023-06-21              28   2024-04-06
# 37               8   2022-08-19              18   2023-06-21
# 38               8   2022-08-19              28   2024-04-06
# 39              19   2023-07-11              29   2024-05-25
# 40               9   2022-09-08              19   2023-07-11
# 41               9   2022-09-08              29   2024-05-25
# 42              10   2022-10-13              30   2024-06-13
# 43              10   2022-10-13              20   2023-08-27
# 44              20   2023-08-27              30   2024-06-13
#
#          cliente_nome
# 0          João Silva
# 1          João Silva
# 2          João Silva
# 3          João Silva
# 4          João Silva
# 5          João Silva
# 6         Maria Souza
# 7         Maria Souza
# 8         Maria Souza
# 9         Maria Souza
# 10        Maria Souza
# 11        Maria Souza
# 12     Carlos Pereira
# 13     Carlos Pereira
# 14     Carlos Pereira
# 15     Carlos Pereira
# 16     Carlos Pereira
# 17     Carlos Pereira
# 18           Ana Lima
# 19           Ana Lima
# 20           Ana Lima
# 21           Ana Lima
# 22           Ana Lima
# 23           Ana Lima
# 24       Bruno Santos
# 25       Bruno Santos
# 26       Bruno Santos
# 27       Bruno Santos
# 28       Bruno Santos
# 29       Bruno Santos
# 30  Fernanda Oliveira
# 31  Fernanda Oliveira
# 32  Fernanda Oliveira
# 33      Ricardo Costa
# 34      Ricardo Costa
# 35      Ricardo Costa
# 36   Patricia Almeida
# 37   Patricia Almeida
# 38   Patricia Almeida
# 39    Gustavo Barbosa
# 40    Gustavo Barbosa
# 41    Gustavo Barbosa
# 42    Juliana Martins
# 43    Juliana Martins
# 44    Juliana Martins

# %%
# 2) Self Join na tabela cliente para encontrar clientes com o mesmo telefone

pd.read_sql_query("""

  SELECT
    c1.codigo AS codigo_cliente_1,
    c1.nome AS nome_cliente_1,
    c2.codigo AS codigo_cliente_2,
    c2.nome AS nome_cliente_2,
    c1.telefone
FROM cliente c1
JOIN cliente c2 ON c1.telefone = c2.telefone
WHERE c1.codigo <> c2.codigo;

""", run)
# Out:
# Empty DataFrame
# Columns: [codigo_cliente_1, nome_cliente_1, codigo_cliente_2, nome_cliente_2, telefone]
# Index: []

# %%
# 3) Consulta que identifica pagamentos que estão em atraso

pd.read_sql_query("""

  CREATE VIEW pagamentos_pendentes AS
  SELECT
      pagamento.codigo AS pagamento_codigo,
      pagamento.data_vencimento,
      pagamento.data_pagamento,
      pagamento.valor,
      cliente.nome AS cliente_nome,
      metodo_pagamento.descricao AS metodo_pagamento,
      status_pagamento.descricao AS status_pagamento
  FROM
      pagamento
  JOIN
      compra ON pagamento.fk_compra_codigo = compra.codigo
  JOIN
      cliente ON compra.fk_cliente_codigo = cliente.codigo
  JOIN
      metodo_pagamento ON pagamento.fk_metodo_pagamento_codigo = metodo_pagamento.codigo
  JOIN
      status_pagamento ON pagamento.fk_status_pagamento_codigo = status_pagamento.codigo
  WHERE
      status_pagamento.descricao = 'Atrasado';

  SELECT * FROM pagamentos_pendentes
  ORDER BY data_vencimento DESC;

""", run)
# Out:
#    pagamento_codigo data_vencimento data_pagamento    valor     cliente_nome  \
# 0                35      2024-12-29     2024-12-29   4200.0     Bruno Santos
# 1                34      2024-12-16     2024-12-16   6100.0         Ana Lima
# 2                33      2024-11-05     2024-11-05   3400.0   Carlos Pereira
# 3                24      2024-02-05     2024-02-05   1550.0         Ana Lima
# 4                23      2024-01-16     2024-01-16  12100.0   Carlos Pereira
# 5                22      2023-12-07     2023-12-07  10050.0      Maria Souza
# 6                21      2023-11-30     2023-11-30   2800.0       João Silva
# 7                10      2022-11-14     2022-11-14   7000.0  Juliana Martins
# 8                 9      2022-10-21     2022-10-21   1500.0  Gustavo Barbosa
#
#     metodo_pagamento status_pagamento
# 0                Pix         Atrasado
# 1   Cartão de Débito         Atrasado
# 2  Cartão de Crédito         Atrasado
# 3           Dinheiro         Atrasado
# 4                Pix         Atrasado
# 5   Cartão de Débito         Atrasado
# 6  Cartão de Crédito         Atrasado
# 7   Cartão de Débito         Atrasado
# 8  Cartão de Crédito         Atrasado

# %%
# 5) View dos produtos mais vendidos


pd.read_sql_query("""

  CREATE VIEW view_produtos_mais_vendidos AS
  SELECT
      p.descricao AS descricao_produto,
      SUM(ci.quantidade) AS quantidade_total_vendida
  FROM compra_item ci
  JOIN produto p ON ci.fk_produto_codigo = p.codigo
  GROUP BY p.descricao
  ORDER BY quantidade_total_vendida DESC;

  SELECT * FROM view_produtos_mais_vendidos;

""",run)
# Out:
#    descricao_produto  quantidade_total_vendida
# 0             Casaco                         3
# 1             Camisa                         3
# 2              Blusa                         3
# 3            Moletom                         3
# 4            Vestido                         3
# 5            Chinelo                         2
# 6               Saia                         2
# 7           Sandália                         2
# 8            Bermuda                         2
# 9              Short                         2
# 10           Jaqueta                         2
# 11             Calça                         2
# 12       Calça Jeans                         2
# 13             Tênis                         2
# 14              Bota                         2

# %%
# 6) Compras de clientes que compraram mais de uma vez no mesmo dia

pd.read_sql_query("""

CREATE VIEW compras_mesmo_dia AS
SELECT
    c1.codigo AS compra1_codigo,
    c1.data_compra AS compra1_data,
    c2.codigo AS compra2_codigo,
    c2.data_compra AS compra2_data,
    cliente.nome AS cliente_nome
FROM
    compra c1
JOIN
    compra c2 ON c1.fk_cliente_codigo = c2.fk_cliente_codigo
            AND c1.data_compra = c2.data_compra
            AND c1.codigo < c2.codigo
JOIN
    cliente ON c1.fk_cliente_codigo = cliente.codigo;

SELECT * FROM compras_mesmo_dia;


""", run)
# Out:
# Empty DataFrame
# Columns: [compra1_codigo, compra1_data, compra2_codigo, compra2_data, cliente_nome]
# Index: []

# %% [markdown]
# # **6.10 SUBCONSULTAS (Mínimo 4)**
# - a) Criar minimo 1 envolvendo GROUP BY
# - b) Criar minimo 1 envolvendo algum tipo de junção

# %%
# 1) Clientes que realizaram mais de uma compra

pd.read_sql_query("""

  SELECT cliente.nome, COUNT(compra.codigo) AS num_compras
  FROM cliente
  JOIN compra ON cliente.codigo = compra.fk_cliente_codigo
  GROUP BY cliente.nome
  HAVING COUNT(compra.codigo) > 1;

""", run)
# Out:
#                 nome  num_compras
# 0     Carlos Pereira            4
# 1    Gustavo Barbosa            3
# 2   Patricia Almeida            3
# 3      Ricardo Costa            3
# 4       Bruno Santos            4
# 5        Maria Souza            4
# 6           Ana Lima            4
# 7         João Silva            4
# 8    Juliana Martins            3
# 9  Fernanda Oliveira            3

# %%
# 2) Produtos mais vendidos por categoria

pd.read_sql_query("""

  SELECT categoria.descricao AS categoria, produto.descricao AS produto, SUM(compra_item.quantidade) AS total_vendido
  FROM categoria
  JOIN produto ON categoria.codigo = produto.fk_categoria_codigo
  JOIN compra_item ON produto.codigo = compra_item.fk_produto_codigo
  GROUP BY categoria.descricao, produto.descricao
  ORDER BY categoria.descricao, total_vendido DESC;

""", run)
# Out:
#    categoria      produto  total_vendido
# 0    Calçado      Chinelo              2
# 1    Calçado        Tênis              2
# 2    Calçado     Sandália              2
# 3    Calçado         Bota              2
# 4      Roupa      Vestido              3
# 5      Roupa      Moletom              3
# 6      Roupa       Casaco              3
# 7      Roupa       Camisa              3
# 8      Roupa        Blusa              3
# 9      Roupa      Jaqueta              2
# 10     Roupa         Saia              2
# 11     Roupa        Calça              2
# 12     Roupa        Short              2
# 13     Roupa  Calça Jeans              2
# 14     Roupa      Bermuda              2

# %%
# 3) Clientes com pagamentos em atraso

pd.read_sql_query("""

SELECT cliente.nome, pagamento.data_vencimento, pagamento.valor
FROM cliente
JOIN compra ON cliente.codigo = compra.fk_cliente_codigo
JOIN pagamento ON compra.codigo = pagamento.fk_compra_codigo
WHERE pagamento.fk_status_pagamento_codigo = (SELECT codigo FROM status_pagamento WHERE descricao = 'Atrasado');

""", run)
# Out:
#               nome data_vencimento    valor
# 0  Gustavo Barbosa      2022-10-21   1500.0
# 1  Juliana Martins      2022-11-14   7000.0
# 2       João Silva      2023-11-30   2800.0
# 3      Maria Souza      2023-12-07  10050.0
# 4   Carlos Pereira      2024-01-16  12100.0
# 5         Ana Lima      2024-02-05   1550.0
# 6   Carlos Pereira      2024-11-05   3400.0
# 7         Ana Lima      2024-12-16   6100.0
# 8     Bruno Santos      2024-12-29   4200.0

# %%
# 4) Clientes que gastaram mais de R$5.000 em suas compras

pd.read_sql_query("""

SELECT cliente.nome, SUM(compra_item.valor * compra_item.quantidade) AS total_gasto
FROM cliente
JOIN compra ON cliente.codigo = compra.fk_cliente_codigo
JOIN compra_item ON compra.codigo = compra_item.fk_compra_codigo
GROUP BY cliente.nome
HAVING SUM(compra_item.valor * compra_item.quantidade) > 5000;

""", run)
# Out:
#                 nome  total_gasto
# 0     Carlos Pereira      20800.0
# 1    Gustavo Barbosa      10850.0
# 2   Patricia Almeida      17650.0
# 3      Ricardo Costa      23750.0
# 4       Bruno Santos      18150.0
# 5        Maria Souza      31650.0
# 6           Ana Lima      16750.0
# 7         João Silva      16900.0
# 8    Juliana Martins      14050.0
# 9  Fernanda Oliveira      11250.0
